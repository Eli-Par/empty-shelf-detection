# %%
# Set up: clone repo and install dependencies (Colab)
# !git clone https://github.com/epar4620/empty-shelf-detection.git
# %cd empty-shelf-detection
# !pip install -r requirements.txt
# !pip install -e .

# %% [markdown]
# # Empty Shelf Detection: Colab Setup
# This notebook is ready to run on Google Colab. The first cell will clone the repository and install all dependencies.

# %%
# (This cell is now handled by the new setup cell above and can be removed or left empty in Colab)
# Out:
# Running cells with 'venv (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Eli/Documents/Programming Projects/VS Code/empty-shelf-detection/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
from training.train import train
train()
# Out:
# Running cells with 'venv (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Eli/Documents/Programming Projects/VS Code/empty-shelf-detection/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# Optional: Check for GPU availability in Colab
import torch
if torch.cuda.is_available():
    print('GPU is available!')
else:
    print('GPU is NOT available.')
